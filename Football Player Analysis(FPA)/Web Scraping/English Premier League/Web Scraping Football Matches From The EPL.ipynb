# %% [markdown]
# Football Player Analysis(FPA)

# %% [markdown]
# Web Scraping Football Matches From The EPL With Python

# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/5bfb9659/Leeds-United-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/33c895d4/Southampton-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/33c895d4/Southampton-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats']

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches
# Out:
# [          Date   Time            Comp         Round  Day Venue Result   GF  \
#  0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
#  1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
#  2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
#  3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
#  4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
#  5   2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
#  6   2022-09-08  18:45       Europa Lg   Group stage  Thu  Away      W  2.0
#  7   2022-09-11  14:00  Premier League   Matchweek 7  Sun  Home    NaN  NaN
#  8   2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
#  9   2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
#  10  2022-10-06  20:00       Europa Lg   Group stage  Thu  Home      W  3.0
#  11  2022-10-09  16:30  Premier League  Matchweek 10  Sun  Home      W  3.0
#  12  2022-10-13  18:45       Europa Lg   Group stage  Thu  Away      W  1.0
#  13  2022-10-16  14:00  Premier League  Matchweek 11  Sun  Away      W  1.0
#  14  2022-10-19  19:30  Premier League  Matchweek 12  Wed  Home    NaN  NaN
#  15  2022-10-20  18:00       Europa Lg   Group stage  Thu  Home      W  1.0
#  16  2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      D  1.0
#  17  2022-10-27  18:45       Europa Lg   Group stage  Thu  Away      L  0.0
#  18  2022-10-30  14:00  Premier League  Matchweek 14  Sun  Home      W  5.0
#  19  2022-11-03  20:00       Europa Lg   Group stage  Thu  Home      W  1.0
#  20  2022-11-06  12:00  Premier League  Matchweek 15  Sun  Away      W  1.0
#  21  2022-11-09  19:45         EFL Cup   Third round  Wed  Home      L  1.0
#  22  2022-11-12  19:45  Premier League  Matchweek 16  Sat  Away      W  2.0
#  23  2022-12-26  20:00  Premier League  Matchweek 17  Mon  Home    NaN  NaN
#  24  2022-12-31  17:30  Premier League  Matchweek 18  Sat  Away    NaN  NaN
#  25  2023-01-03  20:00  Premier League  Matchweek 19  Tue  Home    NaN  NaN
#  26  2023-01-15  16:30  Premier League  Matchweek 20  Sun  Away    NaN  NaN
#  27  2023-01-22  16:30  Premier League  Matchweek 21  Sun  Home    NaN  NaN
#  28  2023-02-04  15:00  Premier League  Matchweek 22  Sat  Away    NaN  NaN
#  29  2023-02-11  15:00  Premier League  Matchweek 23  Sat  Home    NaN  NaN
#  30  2023-02-18  15:00  Premier League  Matchweek 24  Sat  Away    NaN  NaN
#  31  2023-02-25  15:00  Premier League  Matchweek 25  Sat  Away    NaN  NaN
#  32  2023-03-04  15:00  Premier League  Matchweek 26  Sat  Home    NaN  NaN
#  33  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Away    NaN  NaN
#  34  2023-03-18  15:00  Premier League  Matchweek 28  Sat  Home    NaN  NaN
#  35  2023-04-01  15:00  Premier League  Matchweek 29  Sat  Home    NaN  NaN
#  36  2023-04-08  15:00  Premier League  Matchweek 30  Sat  Away    NaN  NaN
#  37  2023-04-15  15:00  Premier League  Matchweek 31  Sat  Away    NaN  NaN
#  38  2023-04-22  15:00  Premier League  Matchweek 32  Sat  Home    NaN  NaN
#  39  2023-04-26  20:00  Premier League  Matchweek 33  Wed  Away    NaN  NaN
#  40  2023-04-29  15:00  Premier League  Matchweek 34  Sat  Home    NaN  NaN
#  41  2023-05-06  15:00  Premier League  Matchweek 35  Sat  Away    NaN  NaN
#  42  2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home    NaN  NaN
#  43  2023-05-20  15:00  Premier League  Matchweek 37  Sat  Away    NaN  NaN
#  44  2023-05-28  15:00  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       GA          Opponent   xG  xGA  Poss  Attendance          Captain  \
#  0   0.0    Crystal Palace  1.0  1.2  44.0     25286.0  Martin Ødegaard
#  1   2.0    Leicester City  2.7  0.5  50.0     60033.0  Martin Ødegaard
#  2   0.0       Bournemouth  1.3  0.3  57.0     10423.0  Martin Ødegaard
#  3   1.0            Fulham  2.6  0.8  71.0     60164.0  Martin Ødegaard
#  4   1.0       Aston Villa  2.4  0.4  59.0     60012.0  Martin Ødegaard
#  5   3.0    Manchester Utd  1.3  1.5  60.0     73431.0  Martin Ødegaard
#  6   1.0         ch Zürich  2.3  1.2  69.0     17070.0     Granit Xhaka
#  7   NaN           Everton  NaN  NaN   NaN         NaN              NaN
#  8   0.0         Brentford  1.5  0.5  63.0     17122.0     Granit Xhaka
#  9   1.0         Tottenham  2.4  1.6  64.0     60278.0  Martin Ødegaard
#  10  0.0     no Bodø/Glimt  3.4  0.8  50.0     59724.0     Granit Xhaka
#  11  2.0         Liverpool  2.7  1.1  43.0     60059.0  Martin Ødegaard
#  12  0.0     no Bodø/Glimt  0.7  0.5  55.0      7922.0  Martin Ødegaard
#  13  0.0      Leeds United  0.5  1.8  53.0     36700.0  Martin Ødegaard
#  14  NaN   Manchester City  NaN  NaN   NaN         NaN              NaN
#  15  0.0  nl PSV Eindhoven  2.7  0.3  62.0     52200.0     Granit Xhaka
#  16  1.0       Southampton  1.0  0.7  59.0     31145.0  Martin Ødegaard
#  17  2.0  nl PSV Eindhoven  1.4  0.8  68.0     35000.0  Martin Ødegaard
#  18  0.0   Nott'ham Forest  2.3  0.4  69.0     60263.0  Martin Ødegaard
#  19  0.0         ch Zürich  1.6  0.4  55.0     48500.0    Gabriel Jesus
#  20  0.0           Chelsea  2.1  0.3  55.0     40142.0  Martin Ødegaard
#  21  3.0          Brighton  NaN  NaN  57.0     59233.0      Rob Holding
#  22  0.0            Wolves  2.1  0.7  62.0     34624.0  Martin Ødegaard
#  23  NaN          West Ham  NaN  NaN   NaN         NaN              NaN
#  24  NaN          Brighton  NaN  NaN   NaN         NaN              NaN
#  25  NaN     Newcastle Utd  NaN  NaN   NaN         NaN              NaN
#  26  NaN         Tottenham  NaN  NaN   NaN         NaN              NaN
#  27  NaN    Manchester Utd  NaN  NaN   NaN         NaN              NaN
#  28  NaN           Everton  NaN  NaN   NaN         NaN              NaN
#  29  NaN         Brentford  NaN  NaN   NaN         NaN              NaN
#  30  NaN       Aston Villa  NaN  NaN   NaN         NaN              NaN
#  31  NaN    Leicester City  NaN  NaN   NaN         NaN              NaN
#  32  NaN       Bournemouth  NaN  NaN   NaN         NaN              NaN
#  33  NaN            Fulham  NaN  NaN   NaN         NaN              NaN
#  34  NaN    Crystal Palace  NaN  NaN   NaN         NaN              NaN
#  35  NaN      Leeds United  NaN  NaN   NaN         NaN              NaN
#  36  NaN         Liverpool  NaN  NaN   NaN         NaN              NaN
#  37  NaN          West Ham  NaN  NaN   NaN         NaN              NaN
#  38  NaN       Southampton  NaN  NaN   NaN         NaN              NaN
#  39  NaN   Manchester City  NaN  NaN   NaN         NaN              NaN
#  40  NaN           Chelsea  NaN  NaN   NaN         NaN              NaN
#  41  NaN     Newcastle Utd  NaN  NaN   NaN         NaN              NaN
#  42  NaN          Brighton  NaN  NaN   NaN         NaN              NaN
#  43  NaN   Nott'ham Forest  NaN  NaN   NaN         NaN              NaN
#  44  NaN            Wolves  NaN  NaN   NaN         NaN              NaN
#
#     Formation              Referee  Match Report            Notes
#  0      4-3-3       Anthony Taylor  Match Report              NaN
#  1      4-3-3       Darren England  Match Report              NaN
#  2      4-3-3         Craig Pawson  Match Report              NaN
#  3      4-3-3       Jarred Gillett  Match Report              NaN
#  4      4-3-3         Robert Jones  Match Report              NaN
#  5      4-3-3         Paul Tierney  Match Report              NaN
#  6      4-3-3    Mohammed Al Hakim  Match Report              NaN
#  7        NaN                  NaN           NaN  Match Postponed
#  8      4-3-3          David Coote  Match Report              NaN
#  9      4-3-3       Anthony Taylor  Match Report              NaN
#  10     4-3-3          Harm Osmers  Match Report              NaN
#  11     4-3-3       Michael Oliver  Match Report              NaN
#  12     4-3-3         Irfan Peljto  Match Report              NaN
#  13     4-3-3       Chris Kavanagh  Match Report              NaN
#  14       NaN                  NaN           NaN  Match Postponed
#  15     4-3-3  Alejandro Hernández  Match Report              NaN
#  16     4-3-3         Robert Jones  Match Report              NaN
#  17     4-3-3       Marco Di Bello  Match Report              NaN
#  18     4-3-3         Simon Hooper  Match Report              NaN
#  19     4-3-3      Erik Lambrechts  Match Report              NaN
#  20     4-3-3       Michael Oliver  Match Report              NaN
#  21   4-2-3-1       Jarred Gillett  Match Report              NaN
#  22     4-3-3       Stuart Attwell  Match Report              NaN
#  23       NaN                  NaN  Head-to-Head              NaN
#  24       NaN                  NaN  Head-to-Head              NaN
#  25       NaN                  NaN  Head-to-Head              NaN
#  26       NaN                  NaN  Head-to-Head              NaN
#  27       NaN                  NaN  Head-to-Head              NaN
#  28       NaN                  NaN  Head-to-Head              NaN
#  29       NaN                  NaN  Head-to-Head              NaN
#  30       NaN                  NaN  Head-to-Head              NaN
#  31       NaN                  NaN  Head-to-Head              NaN
#  32       NaN                  NaN  Head-to-Head              NaN
#  33       NaN                  NaN  Head-to-Head              NaN
#  34       NaN                  NaN  Head-to-Head              NaN
#  35       NaN                  NaN  Head-to-Head              NaN
#  36       NaN                  NaN  Head-to-Head              NaN
#  37       NaN                  NaN  Head-to-Head              NaN
#  38       NaN                  NaN  Head-to-Head              NaN
#  39       NaN                  NaN  Head-to-Head              NaN
#  40       NaN                  NaN  Head-to-Head              NaN
#  41       NaN                  NaN  Head-to-Head              NaN
#  42       NaN                  NaN  Head-to-Head              NaN
#  43       NaN                  NaN  Head-to-Head              NaN
#  44       NaN                  NaN  Head-to-Head              NaN  ]

# %%
matches[0].head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          Opponent   xG  xGA  Poss  Attendance          Captain Formation  \
# 0  Crystal Palace  1.0  1.2  44.0     25286.0  Martin Ødegaard     4-3-3
# 1  Leicester City  2.7  0.5  50.0     60033.0  Martin Ødegaard     4-3-3
# 2     Bournemouth  1.3  0.3  57.0     10423.0  Martin Ødegaard     4-3-3
# 3          Fulham  2.6  0.8  71.0     60164.0  Martin Ødegaard     4-3-3
# 4     Aston Villa  2.4  0.4  59.0     60012.0  Martin Ødegaard     4-3-3
#
#           Referee  Match Report Notes
# 0  Anthony Taylor  Match Report   NaN
# 1  Darren England  Match Report   NaN
# 2    Craig Pawson  Match Report   NaN
# 3  Jarred Gillett  Match Report   NaN
# 4    Robert Jones  Match Report   NaN

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links =  [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/18bb7c10/2022-2023/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions',
#  '/en/squads/18bb7c10/2022-2023/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions',
#  '/en/squads/18bb7c10/2022-2023/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions',
#  '/en/squads/18bb7c10/2022-2023/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Arsenal                                                              \
#          Date   Time            Comp        Round  Day Venue Result GF GA
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2  0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4  2
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3  0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2  1
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2  1
#
#                    ... Standard               Expected                    \
#          Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0  Crystal Palace  ...     14.6  1.0  0     0      1.0  1.0    0.10  0.0
# 1  Leicester City  ...     13.0  0.0  0     0      2.7  2.7    0.16  1.3
# 2     Bournemouth  ...     14.8  0.0  0     0      1.3  1.3    0.10  1.7
# 3          Fulham  ...     15.5  1.0  0     0      2.6  2.6    0.12 -0.6
# 4     Aston Villa  ...     16.3  1.0  0     0      2.4  2.4    0.12 -0.4
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0     0.0        Match Report
# 1     1.3        Match Report
# 2     1.7        Match Report
# 3    -0.6        Match Report
# 4    -0.4        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W   2   0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   2
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W   3   0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W   2   1
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   2   1
#
#          Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  Crystal Palace  ...  14.6  1.0   0      0  1.0   1.0     0.10   0.0
# 1  Leicester City  ...  13.0  0.0   0      0  2.7   2.7     0.16   1.3
# 2     Bournemouth  ...  14.8  0.0   0      0  1.3   1.3     0.10   1.7
# 3          Fulham  ...  15.5  1.0   0      0  2.6   2.6     0.12  -0.6
# 4     Aston Villa  ...  16.3  1.0   0      0  2.4   2.4     0.12  -0.4
#
#    np:G-xG  Match Report
# 0      0.0  Match Report
# 1      1.3  Match Report
# 2      1.7  Match Report
# 3     -0.6  Match Report
# 4     -0.4  Match Report
#
# [5 rows x 26 columns]

# %%
shooting["Date"]
# Out:
# 0     2022-08-05
# 1     2022-08-13
# 2     2022-08-20
# 3     2022-08-27
# 4     2022-08-31
# 5     2022-09-04
# 6     2022-09-08
# 7     2022-09-18
# 8     2022-10-01
# 9     2022-10-06
# 10    2022-10-09
# 11    2022-10-13
# 12    2022-10-16
# 13    2022-10-20
# 14    2022-10-23
# 15    2022-10-27
# 16    2022-10-30
# 17    2022-11-03
# 18    2022-11-06
# 19    2022-11-09
# 20    2022-11-12
# 21           NaN
# Name: Date, dtype: object

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on = "Date")

# %%
team_data.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          Opponent  ...  Formation         Referee  Match Report  Notes  Sh  \
# 0  Crystal Palace  ...      4-3-3  Anthony Taylor  Match Report    NaN  10
# 1  Leicester City  ...      4-3-3  Darren England  Match Report    NaN  19
# 2     Bournemouth  ...      4-3-3    Craig Pawson  Match Report    NaN  14
# 3          Fulham  ...      4-3-3  Jarred Gillett  Match Report    NaN  22
# 4     Aston Villa  ...      4-3-3    Robert Jones  Match Report    NaN  22
#
#   SoT  Dist   FK PK  PKatt
# 0   2  14.6  1.0  0      0
# 1   7  13.0  0.0  0      0
# 2   6  14.8  0.0  0      0
# 3   8  15.5  1.0  0      0
# 4   8  16.3  1.0  0      0
#
# [5 rows x 25 columns]

# %%
team_data
# Out:
#           Date   Time            Comp         Round  Day Venue Result   GF  \
# 0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5   2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 6   2022-09-08  18:45       Europa Lg   Group stage  Thu  Away      W  2.0
# 7   2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8   2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# 9   2022-10-06  20:00       Europa Lg   Group stage  Thu  Home      W  3.0
# 10  2022-10-09  16:30  Premier League  Matchweek 10  Sun  Home      W  3.0
# 11  2022-10-13  18:45       Europa Lg   Group stage  Thu  Away      W  1.0
# 12  2022-10-16  14:00  Premier League  Matchweek 11  Sun  Away      W  1.0
# 13  2022-10-20  18:00       Europa Lg   Group stage  Thu  Home      W  1.0
# 14  2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      D  1.0
# 15  2022-10-27  18:45       Europa Lg   Group stage  Thu  Away      L  0.0
# 16  2022-10-30  14:00  Premier League  Matchweek 14  Sun  Home      W  5.0
# 17  2022-11-03  20:00       Europa Lg   Group stage  Thu  Home      W  1.0
# 18  2022-11-06  12:00  Premier League  Matchweek 15  Sun  Away      W  1.0
# 19  2022-11-09  19:45         EFL Cup   Third round  Wed  Home      L  1.0
# 20  2022-11-12  19:45  Premier League  Matchweek 16  Sat  Away      W  2.0
#
#      GA          Opponent  ...  Formation              Referee  Match Report  \
# 0   0.0    Crystal Palace  ...      4-3-3       Anthony Taylor  Match Report
# 1   2.0    Leicester City  ...      4-3-3       Darren England  Match Report
# 2   0.0       Bournemouth  ...      4-3-3         Craig Pawson  Match Report
# 3   1.0            Fulham  ...      4-3-3       Jarred Gillett  Match Report
# 4   1.0       Aston Villa  ...      4-3-3         Robert Jones  Match Report
# 5   3.0    Manchester Utd  ...      4-3-3         Paul Tierney  Match Report
# 6   1.0         ch Zürich  ...      4-3-3    Mohammed Al Hakim  Match Report
# 7   0.0         Brentford  ...      4-3-3          David Coote  Match Report
# 8   1.0         Tottenham  ...      4-3-3       Anthony Taylor  Match Report
# 9   0.0     no Bodø/Glimt  ...      4-3-3          Harm Osmers  Match Report
# 10  2.0         Liverpool  ...      4-3-3       Michael Oliver  Match Report
# 11  0.0     no Bodø/Glimt  ...      4-3-3         Irfan Peljto  Match Report
# 12  0.0      Leeds United  ...      4-3-3       Chris Kavanagh  Match Report
# 13  0.0  nl PSV Eindhoven  ...      4-3-3  Alejandro Hernández  Match Report
# 14  1.0       Southampton  ...      4-3-3         Robert Jones  Match Report
# 15  2.0  nl PSV Eindhoven  ...      4-3-3       Marco Di Bello  Match Report
# 16  0.0   Nott'ham Forest  ...      4-3-3         Simon Hooper  Match Report
# 17  0.0         ch Zürich  ...      4-3-3      Erik Lambrechts  Match Report
# 18  0.0           Chelsea  ...      4-3-3       Michael Oliver  Match Report
# 19  3.0          Brighton  ...    4-2-3-1       Jarred Gillett  Match Report
# 20  0.0            Wolves  ...      4-3-3       Stuart Attwell  Match Report
#
#     Notes  Sh SoT  Dist   FK PK  PKatt
# 0     NaN  10   2  14.6  1.0  0      0
# 1     NaN  19   7  13.0  0.0  0      0
# 2     NaN  14   6  14.8  0.0  0      0
# 3     NaN  22   8  15.5  1.0  0      0
# 4     NaN  22   8  16.3  1.0  0      0
# 5     NaN  16   3  18.6  1.0  0      0
# 6     NaN  18   8  15.4  0.0  0      0
# 7     NaN  13   7  18.2  0.0  0      0
# 8     NaN  22   9  18.6  1.0  0      0
# 9     NaN  18   6  14.7  1.0  0      0
# 10    NaN  10   6  14.3  0.0  1      1
# 11    NaN   7   1  17.2  0.0  0      0
# 12    NaN   9   4  16.6  1.0  0      0
# 13    NaN  25   8  16.2  2.0  0      0
# 14    NaN  12   3  17.2  0.0  0      0
# 15    NaN  15   3  17.3  0.0  0      0
# 16    NaN  24   9  16.0  1.0  0      0
# 17    NaN  17   4  15.9  0.0  0      0
# 18    NaN  14   2  14.5  0.0  0      0
# 19    NaN  23   4   NaN  NaN  0      0
# 20    NaN  14   3  13.7  0.0  0      0
#
# [21 rows x 25 columns]

# %%
matches[0].shape
# Out:
# (45, 19)

# %%
shooting.shape
# Out:
# (22, 26)

# %% [markdown]
# Multiple teams for Multiple years

# %%
years = list(range(2023,2021, -1))

# %%
years
# Out:
# [2023, 2022]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")

# %%
team_url
# Out:
# 'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats'

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1]

# %%
team_url.split("/")[-1]
# Out:
# 'Wolverhampton-Wanderers-Stats'

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "")

# %%
team_url.split("/")[-1].replace("-Stats", "")
# Out:
# 'Wolverhampton-Wanderers'

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

# %%
team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
# Out:
# 'Wolverhampton Wanderers'

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 40

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L    0
# 39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L    0
# 40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L    0
# 41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D    1
# 42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L    0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk   pk  \
# 0   0.0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0
# 1   2.0  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0
# 2   0.0     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0
# 3   1.0          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0
# 4   1.0     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0
# ..  ...             ...  ...           ...    ...   ...  ...   ...  ...  ...
# 38    2     Aston Villa  ...  Match Report    NaN   9.0  3.0  21.6  0.0  0.0
# 39    4        West Ham  ...  Match Report    NaN   8.0  2.0  22.2  1.0  0.0
# 40    3  Leicester City  ...  Match Report    NaN   9.0  5.0  17.0  0.0  0.0
# 41    1          Wolves  ...  Match Report    NaN  11.0  2.0  14.4  0.0  0.0
# 42    5       Tottenham  ...  Match Report    NaN   9.0  0.0  18.6  0.0  0.0
#
#    pkatt season          team
# 0    0.0   2023       Arsenal
# 1    0.0   2023       Arsenal
# 2    0.0   2023       Arsenal
# 3    0.0   2023       Arsenal
# 4    0.0   2023       Arsenal
# ..   ...    ...           ...
# 38   0.0   2022  Norwich City
# 39   0.0   2022  Norwich City
# 40   0.0   2022  Norwich City
# 41   0.0   2022  Norwich City
# 42   0.0   2022  Norwich City
#
# [1052 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")
